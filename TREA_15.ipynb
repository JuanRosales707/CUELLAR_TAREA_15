# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanRosales707/CUELLAR_TAREA_15/blob/develop/TREA_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalar chromadb
# !pip install chromadb --quiet
# !pip install sentence-transformers --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 89.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 20.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 72.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 94.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.2/71.2 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 30.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 74.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.1/453.1 kB 18.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.7 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 64.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 56.1 MB/s eta 0:00:00

# %%
# Importar librerías necesarias
import chromadb
from chromadb.config import Settings
from sentence_transformers import SentenceTransformer

# %%
# Crear la base de datos local y colección
client = chromadb.PersistentClient(path="./db")
collection = client.get_or_create_collection(name="Tecsup")

# %%
# Información personalizada (Gerbert y amigos)
documentos = [
    "Mi nombre es Gerbert. Tengo 18 años y estudio Big Data y Ciencia de Datos en Lima. Me apasiona mantenerme activo y explorar nuevas ideas. Suelo decir: 'Siempre hay espacio para aprender más'.",
    "Sofía, tiene 20 años y también estudia Big Data y Ciencia de Datos en Lima. Disfruta descubrir nuevas perspectivas mientras descanso. Mi lema es: 'Cada día trae su propio aprendizaje'.",
    "Óscar, tiene 25 años. Estudia Big Data y Ciencia de Datos en Lima. Le gusta despejar la mente a través del ejercicio y actividades recreativas. Siempre digo: 'Nada mejor que avanzar paso a paso'.",
    "Julio. Tiene 19 años y es estudiante de Big Data y Ciencia de Datos en Lima. Encuentra placer en conectar ideas con personas. Suele decir: 'La clave está en compartir lo que sabes'."
]
# Agregar los documentos con IDs únicos
collection.add(
    documents=documentos,
    ids=["gerbert", "sofia", "oscar", "julio"]
)

# %%
# Crear un prompt (consulta)
prompt = "¿Quién estudia en Lima y disfruta mantenerse activo?"
resultados = collection.query(
    query_texts=[prompt],
    n_results=2
)

# Mostrar resultados
print("Consulta:", prompt)
for r in resultados['documents'][0]:
    print("\nResultado:\n", r)
# Out:
# Consulta: ¿Quién estudia en Lima y disfruta mantenerse activo?
#
# Resultado:
#  Óscar, tiene 25 años. Estudia Big Data y Ciencia de Datos en Lima. Le gusta despejar la mente a través del ejercicio y actividades recreativas. Siempre digo: 'Nada mejor que avanzar paso a paso'.
#
# Resultado:
#  Julio. Tiene 19 años y es estudiante de Big Data y Ciencia de Datos en Lima. Encuentra placer en conectar ideas con personas. Suele decir: 'La clave está en compartir lo que sabes'.

# %%
# Visualizar lo que hay en la colección
print("\n--- Datos en la base vectorial 'Tecsup' ---")
print(collection.peek(4))  # mostrar los 4 documentos insertados
# Out:
# --- Datos en la base vectorial 'Tecsup' ---
# {'ids': ['gerbert', 'sofia', 'oscar', 'julio'], 'embeddings': array([[ 0.07836602,  0.01865706, -0.04368613, ..., -0.00105731,
#         -0.09397091,  0.01598102],
#        [ 0.07872462, -0.03564658, -0.02934462, ...,  0.06128772,
#         -0.05645502, -0.04774531],
#        [ 0.05447517, -0.02419662, -0.01889989, ...,  0.04984304,
#         -0.07238444, -0.03825652],
#        [ 0.05567755, -0.04318005, -0.05069941, ...,  0.0486171 ,
#         -0.13435131,  0.00586598]]), 'documents': ["Mi nombre es Gerbert. Tengo 18 años y estudio Big Data y Ciencia de Datos en Lima. Me apasiona mantenerme activo y explorar nuevas ideas. Suelo decir: 'Siempre hay espacio para aprender más'.", "Sofía, tiene 20 años y también estudia Big Data y Ciencia de Datos en Lima. Disfruta descubrir nuevas perspectivas mientras descanso. Mi lema es: 'Cada día trae su propio aprendizaje'.", "Óscar, tiene 25 años. Estudia Big Data y Ciencia de Datos en Lima. Le gusta despejar la mente a través del ejercicio y actividades recreativas. Siempre digo: 'Nada mejor que avanzar paso a paso'.", "Julio. Tiene 19 años y es estudiante de Big Data y Ciencia de Datos en Lima. Encuentra placer en conectar ideas con personas. Suele decir: 'La clave está en compartir lo que sabes'."], 'uris': None, 'included': ['metadatas', 'documents', 'embeddings'], 'data': None, 'metadatas': [None, None, None, None]}

# %%
# Comparación con otro motor de embeddings
from sentence_transformers import SentenceTransformer

# Crear nueva colección en el mismo cliente
mini_collection = client.get_or_create_collection(name="Tecsup_MiniLM")

# Cargar el modelo all-MiniLM-L6-v2
modelo_mini = SentenceTransformer('all-MiniLM-L6-v2')

# Convertir documentos en vectores
vectores_mini = modelo_mini.encode(documentos).tolist()

# Agregar a la nueva colección
mini_collection.add(
    documents=documentos,
    ids=["gerbert_m", "sofia_m", "oscar_m", "julio_m"],
    embeddings=vectores_mini
)

# Consultar con el nuevo motor de embeddings
prompt = "¿Quién estudia en Lima y disfruta mantenerse activo?"
vector_prompt = modelo_mini.encode([prompt]).tolist()

resultados_mini = mini_collection.query(
    query_embeddings=vector_prompt,
    n_results=2
)

# Mostrar resultados
print("\n--- Comparación usando el modelo 'all-MiniLM-L6-v2' ---")
print("Consulta:", prompt)
for r in resultados_mini['documents'][0]:
    print("\nResultado:\n", r)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# --- Comparación usando el modelo 'all-MiniLM-L6-v2' ---
# Consulta: ¿Quién estudia en Lima y disfruta mantenerse activo?
#
# Resultado:
#  Óscar, tiene 25 años. Estudia Big Data y Ciencia de Datos en Lima. Le gusta despejar la mente a través del ejercicio y actividades recreativas. Siempre digo: 'Nada mejor que avanzar paso a paso'.
#
# Resultado:
#  Julio. Tiene 19 años y es estudiante de Big Data y Ciencia de Datos en Lima. Encuentra placer en conectar ideas con personas. Suele decir: 'La clave está en compartir lo que sabes'.
